# %%
import pandas as pd
import datetime
import random

# %%
num_records = 30

dates = pd.date_range(start="2021-01-01", end="2021-12-31", periods=num_records)
price = [round(random.uniform(10,100),2) for _ in range(num_records)]
product_id = [random.randint(10, 100) for _ in range(num_records)]
quantity_purchased = [random.randint(1, 10) for _ in range(num_records)]
serial_nos = [ f'SN-{random.randint(1000,9999)}' for _ in range(num_records)]
user_id = ['U' + str(random.randint(10,30)) for _ in range(num_records)]
user_type = ["Retail", "Wholesale"]
user_classes = ["User A", "User B", "User B"]
purchase_weeks = [date.isocalendar()[1] for date in dates]

#creating a dictonary
data = {
    "Date" : dates,
    "Price" : price,
    "Product ID" : product_id,
    "Quantity Purchased" : quantity_purchased,
    "Serial No" : serial_nos,
    "User ID" : user_id,
    "User Type" : random.choices(user_type, k=num_records),
    "User Class" : random.choices(user_classes, k=num_records),
    "Purchased Week" : purchase_weeks
}

df = pd.DataFrame(data)
print("DataFrame", df.head)
# Out:
# DataFrame <bound method NDFrame.head of                             Date  Price  Product ID  Quantity Purchased
# 0  2021-01-01 00:00:00.000000000  57.51          82                   4  \
# 1  2021-01-13 13:14:28.965517241  94.86          25                   7
# 2  2021-01-26 02:28:57.931034482  73.83          19                   8
# 3  2021-02-07 15:43:26.896551724  29.18          67                   8
# 4  2021-02-20 04:57:55.862068965  97.32          87                   5
# 5  2021-03-04 18:12:24.827586207  39.92          27                   8
# 6  2021-03-17 07:26:53.793103448  52.91          65                   8
# 7  2021-03-29 20:41:22.758620690  54.89          98                   3
# 8  2021-04-11 09:55:51.724137931  32.66          47                   2
# 9  2021-04-23 23:10:20.689655172  33.45          96                   4
# 10 2021-05-06 12:24:49.655172414  19.71          25                   2
# 11 2021-05-19 01:39:18.620689656  23.02          10                   6
# 12 2021-05-31 14:53:47.586206896  80.28          14                   4
# 13 2021-06-13 04:08:16.551724138  13.99          69                   6
# 14 2021-06-25 17:22:45.517241380  73.89          47                   6
# 15 2021-07-08 06:37:14.482758620  27.93          47                   3
# 16 2021-07-20 19:51:43.448275862  57.81          64                   2
# 17 2021-08-02 09:06:12.413793104  19.35          78                   6
# 18 2021-08-14 22:20:41.379310344  32.40          83                   4
# 19 2021-08-27 11:35:10.344827588  21.64          87                   7
# 20 2021-09-09 00:49:39.310344828  93.24          15                   6
# 21 2021-09-21 14:04:08.275862068  79.50          65                   1
# 22 2021-10-04 03:18:37.241379312  87.58          94                   4
# 23 2021-10-16 16:33:06.206896552  39.90          73                   7
# 24 2021-10-29 05:47:35.172413792  48.27          49                  10
# 25 2021-11-10 19:02:04.137931036  87.52          85                   5
# 26 2021-11-23 08:16:33.103448276  83.88          58                   9
# 27 2021-12-05 21:31:02.068965516  82.62          86                   5
# 28 2021-12-18 10:45:31.034482760  19.60          25                   5
# 29 2021-12-31 00:00:00.000000000  57.67         100                   1
#
#    Serial No User ID  User Type User Class  Purchased Week
# 0    SN-9693     U24  Wholesale     User B              53
# 1    SN-2302     U23     Retail     User B               2
# 2    SN-6004     U22     Retail     User A               4
# 3    SN-9128     U27  Wholesale     User A               5
# 4    SN-4504     U12     Retail     User B               7
# 5    SN-5651     U18     Retail     User A               9
# 6    SN-3744     U21     Retail     User A              11
# 7    SN-6773     U10     Retail     User A              13
# 8    SN-5300     U22     Retail     User B              14
# 9    SN-3539     U24  Wholesale     User A              16
# 10   SN-6209     U28  Wholesale     User B              18
# 11   SN-3759     U10  Wholesale     User B              20
# 12   SN-8773     U28  Wholesale     User A              22
# 13   SN-1361     U28     Retail     User A              23
# 14   SN-6779     U23  Wholesale     User B              25
# 15   SN-8195     U12  Wholesale     User B              27
# 16   SN-6130     U22     Retail     User B              29
# 17   SN-9680     U10  Wholesale     User A              31
# 18   SN-5375     U18  Wholesale     User B              32
# 19   SN-4196     U19     Retail     User B              34
# 20   SN-4284     U24  Wholesale     User B              36
# 21   SN-9303     U18  Wholesale     User B              38
# 22   SN-9154     U14     Retail     User B              40
# 23   SN-9658     U11  Wholesale     User B              41
# 24   SN-1461     U26     Retail     User B              43
# 25   SN-5920     U16     Retail     User A              45
# 26   SN-9062     U19     Retail     User B              47
# 27   SN-2152     U18  Wholesale     User A              48
# 28   SN-4967     U18     Retail     User B              50
# 29   SN-9469     U27  Wholesale     User A              52  >

# %%
df.to_csv("customer_dataset.csv", index=False)

# %%
#plotting graph
import matplotlib.pyplot as plt
data = pd.read_csv('customer_dataset.csv')
user_id = 'U24'

user_data = data[data["User ID"] == user_id]
plt.figure(figsize=(10,6))
plt.title(f'Price Trend of User ID {user_id}')
plt.plot(user_data["Date"], user_data["Price"], alpha=0.5)
plt.xlabel("Date")
plt.ylabel("Price")
plt.xticks(rotation=45)
plt.legend()
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
plt.figure(figsize=(10,6))
plt.plot(df["Date"], df["Price"], alpha=0.5)
plt.scatter(user_data["Date"], user_data["Price"], color="red", label=f'Price trend of USER ID {user_id}')
plt.xlabel("Date")
plt.ylabel("Price")
plt.xticks(rotation=45)
plt.legend()
plt.show()
