# %%
import pandas as pd
import datetime
import random

# %%
num_records = 30

dates = pd.date_range(start="2021-01-01", end="2021-12-31", periods=num_records)
price = [round(random.uniform(10,100),2) for _ in range(num_records)]
product_id = [random.randint(10, 100) for _ in range(num_records)]
quantity_purchased = [random.randint(1, 10) for _ in range(num_records)]
serial_nos = [ f'SN-{random.randint(1000,9999)}' for _ in range(num_records)]
user_id = ['U' + str(random.randint(10,30)) for _ in range(num_records)]
user_type = ["Retail", "Wholesale"]
user_classes = ["User A", "User B", "User B"]
purchase_weeks = [date.isocalendar()[1] for date in dates]

#creating a dictonary
data = {
    "Date" : dates,
    "Price" : price,
    "Product ID" : product_id,
    "Quantity Purchased" : quantity_purchased,
    "Serial No" : serial_nos,
    "User ID" : user_id,
    "User Type" : random.choices(user_type, k=num_records),
    "User Class" : random.choices(user_classes, k=num_records),
    "Purchased Week" : purchase_weeks
}

df = pd.DataFrame(data)
print("DataFrame", df.head)
# Out:
# DataFrame <bound method NDFrame.head of                             Date  Price  Product ID  Quantity Purchased
# 0  2021-01-01 00:00:00.000000000  41.78          16                  10  \
# 1  2021-01-13 13:14:28.965517241  32.96          56                   6
# 2  2021-01-26 02:28:57.931034482  95.06          45                   7
# 3  2021-02-07 15:43:26.896551724  45.81          61                   9
# 4  2021-02-20 04:57:55.862068965  44.71          50                  10
# 5  2021-03-04 18:12:24.827586207  71.10          73                   7
# 6  2021-03-17 07:26:53.793103448  97.71          72                   1
# 7  2021-03-29 20:41:22.758620690  69.86          82                   9
# 8  2021-04-11 09:55:51.724137931  51.56          72                   9
# 9  2021-04-23 23:10:20.689655172  25.16          34                   5
# 10 2021-05-06 12:24:49.655172414  53.70          81                   3
# 11 2021-05-19 01:39:18.620689656  56.22          32                   5
# 12 2021-05-31 14:53:47.586206896  45.48          80                   7
# 13 2021-06-13 04:08:16.551724138  91.60          30                   8
# 14 2021-06-25 17:22:45.517241380  39.87          71                   8
# 15 2021-07-08 06:37:14.482758620  84.69          18                   2
# 16 2021-07-20 19:51:43.448275862  55.84          42                   9
# 17 2021-08-02 09:06:12.413793104  48.99          58                   9
# 18 2021-08-14 22:20:41.379310344  77.36          75                   4
# 19 2021-08-27 11:35:10.344827588  57.96          55                   5
# 20 2021-09-09 00:49:39.310344828  82.60          17                   9
# 21 2021-09-21 14:04:08.275862068  99.55          20                   6
# 22 2021-10-04 03:18:37.241379312  86.97          70                  10
# 23 2021-10-16 16:33:06.206896552  85.29          42                   8
# 24 2021-10-29 05:47:35.172413792  78.05          69                  10
# 25 2021-11-10 19:02:04.137931036  13.34          58                   5
# 26 2021-11-23 08:16:33.103448276  72.56          95                   3
# 27 2021-12-05 21:31:02.068965516  14.82          66                   4
# 28 2021-12-18 10:45:31.034482760  98.60          84                   9
# 29 2021-12-31 00:00:00.000000000  33.77          43                   5
#
#    Serial No User ID  User Type User Class  Purchased Week
# 0    SN-5439     U13     Retail     User A              53
# 1    SN-3664     U11  Wholesale     User A               2
# 2    SN-3757     U20     Retail     User B               4
# 3    SN-5038     U16  Wholesale     User A               5
# 4    SN-7797     U25     Retail     User A               7
# 5    SN-3622     U22  Wholesale     User A               9
# 6    SN-8567     U16  Wholesale     User A              11
# 7    SN-2347     U17     Retail     User B              13
# 8    SN-1590     U11     Retail     User A              14
# 9    SN-7649     U26     Retail     User A              16
# 10   SN-5677     U18     Retail     User A              18
# 11   SN-5363     U18     Retail     User A              20
# 12   SN-7916     U12  Wholesale     User B              22
# 13   SN-9920     U15  Wholesale     User B              23
# 14   SN-9681     U21  Wholesale     User B              25
# 15   SN-2806     U28     Retail     User B              27
# 16   SN-3467     U13     Retail     User A              29
# 17   SN-4515     U23  Wholesale     User B              31
# 18   SN-3188     U26     Retail     User A              32
# 19   SN-6936     U25  Wholesale     User A              34
# 20   SN-6552     U20     Retail     User B              36
# 21   SN-8848     U29  Wholesale     User B              38
# 22   SN-4470     U21     Retail     User A              40
# 23   SN-2374     U25  Wholesale     User B              41
# 24   SN-4298     U17  Wholesale     User B              43
# 25   SN-7832     U23  Wholesale     User A              45
# 26   SN-7559     U10     Retail     User A              47
# 27   SN-7377     U18  Wholesale     User B              48
# 28   SN-4236     U30  Wholesale     User B              50
# 29   SN-6878     U23  Wholesale     User B              52  >

# %%
df.to_csv("customer_dataset.csv", index=False)

# %%
#plotting graph
import matplotlib.pyplot as plt
df = pd.read_csv("customer_dataset.csv")
user_id = 'U23'

user_data = df[df["User ID"] == user_id]
plt.figure(figsize=(10,6))
plt.plot(user_data["Date"], user_data['Price'], alpha=0.5)
plt.xlabel('Date')
plt.ylabel('Price')
plt.title(f'Price Trend of User ID {user_id}')
plt.xticks(rotation=45)
plt.show()

# %%
plt.figure(figsize=(10, 6))
plt.plot(df['Date'], df['Price'], alpha=0.5)
plt.scatter(user_data['Date'], user_data['Price'], color='red', label=f'User ID {user_id}')
plt.xlabel('Date')
plt.ylabel('Price')
plt.title(f'Price Trends for User ID {user_id} Over Time')
plt.xticks(rotation=45)
plt.legend
plt.show()
