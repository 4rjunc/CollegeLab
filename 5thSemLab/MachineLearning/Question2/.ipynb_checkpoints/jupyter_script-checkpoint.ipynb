# %%
import pandas as pd
import random
import datetime

num_records = 30

dates = pd.date_range(start='2021-01-01', end='2021-12-31', periods=num_records)
price = [round(random.uniform(10,100),2) for _ in range(num_records)]
product_id = [random.randint(10,100) for _ in range(num_records)]
quantity_purchased = [random.randint(1,20) for _ in range(num_records)]
serial_no = [f'SN-{random.randint(1000,9999)}' for _ in range(num_records)]
user_id = [ 'U' + str(random.randint(10,30)) for _ in range(num_records)]
user_type = ["Reatailer", "Wholesale"]
user_class = ["Class A", "Class B", "Class C", "Class D"]
purchased_week = [date.isocalendar()[1] for date in dates]
                  
data = {
    "Date" : dates,
    "Price" : price,
    "Product" : product_id,
    "Quantity Purchased" : quantity_purchased,
    "Serial NO" : serial_no,
    "User ID" : user_id,
    "User Type" : random.choices(user_type, k=num_records),
    "User Class" : random.choices(user_class, k=num_records),
    "Purchased" : purchased_week
}
                  
df = pd.DataFrame(data)
print(df)
#Saving to csv
df.to_csv("customer_dataset.csv", index=False)
# Out:
#                             Date  Price  Product  Quantity Purchased
# 0  2021-01-01 00:00:00.000000000  71.01       37                   5  \
# 1  2021-01-13 13:14:28.965517241  38.49       53                   8
# 2  2021-01-26 02:28:57.931034482  37.11       53                   2
# 3  2021-02-07 15:43:26.896551724  11.36       95                  19
# 4  2021-02-20 04:57:55.862068965  47.69       36                  15
# 5  2021-03-04 18:12:24.827586207  79.01       19                   9
# 6  2021-03-17 07:26:53.793103448  54.93       99                  16
# 7  2021-03-29 20:41:22.758620690  88.48       22                  13
# 8  2021-04-11 09:55:51.724137931  87.13       56                  11
# 9  2021-04-23 23:10:20.689655172  38.67       76                  14
# 10 2021-05-06 12:24:49.655172414  15.64       24                   2
# 11 2021-05-19 01:39:18.620689656  30.91       70                  14
# 12 2021-05-31 14:53:47.586206896  68.55       85                  11
# 13 2021-06-13 04:08:16.551724138  67.13       22                   9
# 14 2021-06-25 17:22:45.517241380  16.79       71                  14
# 15 2021-07-08 06:37:14.482758620  70.10       56                  16
# 16 2021-07-20 19:51:43.448275862  42.95       35                   3
# 17 2021-08-02 09:06:12.413793104  83.51       63                   9
# 18 2021-08-14 22:20:41.379310344  17.01       98                  12
# 19 2021-08-27 11:35:10.344827588  38.34       33                  15
# 20 2021-09-09 00:49:39.310344828  65.76       16                  13
# 21 2021-09-21 14:04:08.275862068  63.14       32                  14
# 22 2021-10-04 03:18:37.241379312  60.63       32                  16
# 23 2021-10-16 16:33:06.206896552  58.87       64                  13
# 24 2021-10-29 05:47:35.172413792  76.14       24                  15
# 25 2021-11-10 19:02:04.137931036  16.93       37                  14
# 26 2021-11-23 08:16:33.103448276  91.12       27                   6
# 27 2021-12-05 21:31:02.068965516  53.06       22                   4
# 28 2021-12-18 10:45:31.034482760  59.79       17                  12
# 29 2021-12-31 00:00:00.000000000  71.83       18                  14
#
#    Serial NO User ID  User Type User Class  Purchased
# 0    SN-5074     U19  Reatailer    Class B         53
# 1    SN-2258     U19  Reatailer    Class A          2
# 2    SN-4668     U16  Wholesale    Class B          4
# 3    SN-8679     U14  Reatailer    Class A          5
# 4    SN-6869     U28  Reatailer    Class C          7
# 5    SN-3387     U24  Wholesale    Class B          9
# 6    SN-1838     U12  Reatailer    Class B         11
# 7    SN-2884     U21  Reatailer    Class A         13
# 8    SN-1064     U19  Reatailer    Class C         14
# 9    SN-2578     U14  Reatailer    Class C         16
# 10   SN-7841     U12  Wholesale    Class A         18
# 11   SN-5156     U23  Wholesale    Class C         20
# 12   SN-8476     U18  Reatailer    Class D         22
# 13   SN-8219     U10  Wholesale    Class D         23
# 14   SN-1819     U10  Reatailer    Class B         25
# 15   SN-7581     U10  Wholesale    Class A         27
# 16   SN-9463     U24  Wholesale    Class A         29
# 17   SN-5872     U12  Reatailer    Class A         31
# 18   SN-1956     U10  Reatailer    Class D         32
# 19   SN-7734     U15  Reatailer    Class A         34
# 20   SN-9234     U11  Reatailer    Class C         36
# 21   SN-5582     U12  Reatailer    Class B         38
# 22   SN-3353     U17  Wholesale    Class B         40
# 23   SN-4908     U20  Wholesale    Class B         41
# 24   SN-1110     U13  Wholesale    Class A         43
# 25   SN-3119     U22  Reatailer    Class B         45
# 26   SN-1180     U18  Wholesale    Class B         47
# 27   SN-7372     U19  Wholesale    Class C         48
# 28   SN-9893     U25  Reatailer    Class B         50
# 29   SN-1182     U17  Wholesale    Class A         52

# %%
import matplotlib.pyplot as plt
df = pd.read_csv('customer_dataset.csv')
#Create box plot Quantity and Week value distribution having parameters of quantity_purchased','purchase_week'.
plt.figure(figsize=(10,6))
plt.boxplot(df['Quantity Purchased'])
plt.xlabel("Quantity Purchased")
plt.title("Distribution of Quantity Purchased")
plt.show()
