# %%
import pandas as pd
df = pd.read_csv('/Users/arjun/Documents/Lab-Programs/5thSemLab/MachineLearning/Datasets/pokemon.csv')
print(df)

#Transforming nominal features
nominal_feature = ["Generation"]
df_nominal = pd.get_dummies(df[nominal_feature])
print(df_nominal)

#Transforming Ordinal Features
gen_ord_map = {
        1:'Gen1', 2:'Gen2', 3:'Gen3',
        4:'Gen4', 5:'Gen5', 6:'Gen6'
}
df["Generation Labels"] = df["Generation"].map(gen_ord_map)

# Encoding categorical features using one-hot encoding scheme
categorical_features = ['Generation', 'Legendary']
df_encoded = pd.get_dummies(df[categorical_features])

df_transformed = pd.concat([df, df_nominal, df_encoded], axis=1)
print("df_transformed", df_transformed)
# Out:
#        #                   Name   Type 1  Type 2  Total  HP  Attack  Defense
# 0      1              Bulbasaur    Grass  Poison    318  45      49       49  \
# 1      2                Ivysaur    Grass  Poison    405  60      62       63
# 2      3               Venusaur    Grass  Poison    525  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison    625  80     100      123
# 4      4             Charmander     Fire     NaN    309  39      52       43
# ..   ...                    ...      ...     ...    ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy    600  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy    700  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost    600  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark    680  80     160       60
# 799  721              Volcanion     Fire   Water    600  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0         65       65     45           1      False
# 1         80       80     60           1      False
# 2        100      100     80           1      False
# 3        122      120     80           1      False
# 4         60       50     65           1      False
# ..       ...      ...    ...         ...        ...
# 795      100      150     50           6       True
# 796      160      110    110           6       True
# 797      150      130     70           6       True
# 798      170      130     80           6       True
# 799      130       90     70           6       True
#
# [800 rows x 13 columns]
#      Generation
# 0             1
# 1             1
# 2             1
# 3             1
# 4             1
# ..          ...
# 795           6
# 796           6
# 797           6
# 798           6
# 799           6
#
# [800 rows x 1 columns]
# df_transformed        #                   Name   Type 1  Type 2  Total  HP  Attack  Defense
# 0      1              Bulbasaur    Grass  Poison    318  45      49       49  \
# 1      2                Ivysaur    Grass  Poison    405  60      62       63
# 2      3               Venusaur    Grass  Poison    525  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison    625  80     100      123
# 4      4             Charmander     Fire     NaN    309  39      52       43
# ..   ...                    ...      ...     ...    ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy    600  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy    700  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost    600  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark    680  80     160       60
# 799  721              Volcanion     Fire   Water    600  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary Generation Labels
# 0         65       65     45           1      False              Gen1  \
# 1         80       80     60           1      False              Gen1
# 2        100      100     80           1      False              Gen1
# 3        122      120     80           1      False              Gen1
# 4         60       50     65           1      False              Gen1
# ..       ...      ...    ...         ...        ...               ...
# 795      100      150     50           6       True              Gen6
# 796      160      110    110           6       True              Gen6
# 797      150      130     70           6       True              Gen6
# 798      170      130     80           6       True              Gen6
# 799      130       90     70           6       True              Gen6
#
#      Generation  Generation  Legendary
# 0             1           1      False
# 1             1           1      False
# 2             1           1      False
# 3             1           1      False
# 4             1           1      False
# ..          ...         ...        ...
# 795           6           6       True
# 796           6           6       True
# 797           6           6       True
# 798           6           6       True
# 799           6           6       True
#
# [800 rows x 17 columns]
