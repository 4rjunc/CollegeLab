# %%
#Mean_Median_GBlur
import cv2
import numpy as np
import matplotlib.pyplot as plt

img = cv2.imread("./images/penguin.jpeg", 0)
blur = cv2.blur(img, (5,5))
median = cv2.medianBlur(img, 5)
gblur = cv2.GaussianBlur(img, (5,5), 0)
plt.figure(figsize=(12,8))

plt.subplot(221)
plt.title("Original Image")
plt.imshow(img)
plt.axis('off')

plt.subplot(222)
plt.title("Blur Image")
plt.imshow(blur)
plt.axis('off')

plt.subplot(223)
plt.title("Median Image")
plt.imshow(median)
plt.axis('off')

plt.subplot(224)
plt.title("Gaussian Blur Image")
plt.imshow(gblur)
plt.axis('off')

plt.show()
