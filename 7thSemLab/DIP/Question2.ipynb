# %%
from PIL import Image

# %%
path = "./images/flower.jpg"
img = Image.open(path)
display("Image", img)

img_rotate = img.rotate(90)
display("Rotate 90", img_rotate)
# Out:
# 'Image'
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1500x1001>
# 'Rotate 90'
# <PIL.Image.Image image mode=RGB size=1500x1001>
